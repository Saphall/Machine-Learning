# %% [markdown]
# # Import necessary library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# # Pandas Structures

# %%
# series = 1-dimensional

series = pd.Series(['BMW','Toyota','Honda'])
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colors=pd.Series(['Red','Blue','White'])
colors
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# dataframe = 2- dimensional

car_data=pd.DataFrame({'car make':series,'colors':colors})
car_data
# Out:
#   car make colors
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %% [markdown]
# # Car_Data
# This is car data analysis.

# %%
# Import Data
car_sales=pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Exporting the dataframe
car_sales.to_csv('export-carsales.csc',index=False)

# %%
exp=pd.read_csv('export-carsales.csc')
exp
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describing data

# %%
#Attributes
car_sales.dtypes

#Function 
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns=car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
#works only on numeric columns
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
# Make             10 non-null object
# Colour           10 non-null object
# Odometer (KM)    10 non-null int64
# Doors            10 non-null int64
# Price            10 non-null object
# dtypes: int64(2), object(3)
# memory usage: 344.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices=pd.Series([3,16,2])
car_prices.median()
# Out:
# 3.0

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Doors'].sum()
# Out:
# 40

# %%
len(car_sales)
#length of rows
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Viewing and Selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#.loc & .iloc
animals=pd.Series(['cats','dog','bird','panda'],index=[0,3,6,8])
animals
# Out:
# 0     cats
# 3      dog
# 6     bird
# 8    panda
# dtype: object

# %%
animals.loc[3]
# Out:
# 'dog'

# %%
#.loc refers to index
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
#.iloc refers to positon
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Colour
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales[car_sales['Make']=='Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Odometer (KM)']>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales['Make'],car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#GroupBy

car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
car_sales['Odometer (KM)'].plot()

# %%
car_sales['Odometer (KM)'].hist()

# %%
car_sales['Price'].dtype
# Out:
# dtype('O')

# %%
#change price column containing values like > $333 to integer
#car_sales['Price']=car_sales['Price'].str.replace('[\$\,\.]','')    #.astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# Remove the two extra zeros at the end of the price column
#car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales.Price.plot()

# %% [markdown]
# ## Manipulating Data

# %%
car_sales['Make'].str.lower()   #doesnot actually replace the actual data
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales.Make=car_sales.Make.str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %% [markdown]
# ### Missing Data

# %%
car_sales_missing =pd.read_csv('car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing.Odometer.mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing.Odometer.mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

#donot use inline cause the data will be forever inplaced and should be imorted next time

# %%
car_sales_missing 
#car_sales_missing.to_csv('dropped-sales.csv')
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
#Columns from series
seats_column=pd.Series([4,4,4,4,4])

#New column called seats
car_sales['Seats']=seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    4.0
# 1   honda    Red          87899      4   500000    4.0
# 2  toyota   Blue          32549      3   700000    4.0
# 3     bmw  Black          11179      5  2200000    4.0
# 4  nissan  White         213095      4   350000    4.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales.Seats.fillna(4,inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    4.0
# 1   honda    Red          87899      4   500000    4.0
# 2  toyota   Blue          32549      3   700000    4.0
# 3     bmw  Black          11179      5  2200000    4.0
# 4  nissan  White         213095      4   350000    4.0
# 5  toyota  Green          99213      4   450000    4.0
# 6   honda   Blue          45698      4   750000    4.0
# 7   honda   Blue          54738      4   700000    4.0
# 8  toyota  White          60000      4   625000    4.0
# 9  nissan  White          31600      4   970000    4.0

# %%
#Column from PYthon list
fuel_economy = [4.3,7.35,3.3,5.33,6.3,7.7,4,5,2,2]
car_sales['Fuel per 100km'] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km
# 0  toyota  White         150043      4   400000    4.0            4.30
# 1   honda    Red          87899      4   500000    4.0            7.35
# 2  toyota   Blue          32549      3   700000    4.0            3.30
# 3     bmw  Black          11179      5  2200000    4.0            5.33
# 4  nissan  White         213095      4   350000    4.0            6.30
# 5  toyota  Green          99213      4   450000    4.0            7.70
# 6   honda   Blue          45698      4   750000    4.0            4.00
# 7   honda   Blue          54738      4   700000    4.0            5.00
# 8  toyota  White          60000      4   625000    4.0            2.00
# 9  nissan  White          31600      4   970000    4.0            2.00

# %%
#making new columns using existing columns

car_sales['Total Fuel used']=car_sales['Odometer (KM)']/100* car_sales['Fuel per 100km']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   400000    4.0            4.30
# 1   honda    Red          87899      4   500000    4.0            7.35
# 2  toyota   Blue          32549      3   700000    4.0            3.30
# 3     bmw  Black          11179      5  2200000    4.0            5.33
# 4  nissan  White         213095      4   350000    4.0            6.30
# 5  toyota  Green          99213      4   450000    4.0            7.70
# 6   honda   Blue          45698      4   750000    4.0            4.00
# 7   honda   Blue          54738      4   700000    4.0            5.00
# 8  toyota  White          60000      4   625000    4.0            2.00
# 9  nissan  White          31600      4   970000    4.0            2.00
#
#    Total Fuel used
# 0        6451.8490
# 1        6460.5765
# 2        1074.1170
# 3         595.8407
# 4       13424.9850
# 5        7639.4010
# 6        1827.9200
# 7        2736.9000
# ...

# %%
#Create a column from single value

car_sales['No of wheels']=6
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   400000    4.0            4.30
# 1   honda    Red          87899      4   500000    4.0            7.35
# 2  toyota   Blue          32549      3   700000    4.0            3.30
# 3     bmw  Black          11179      5  2200000    4.0            5.33
# 4  nissan  White         213095      4   350000    4.0            6.30
# 5  toyota  Green          99213      4   450000    4.0            7.70
# 6   honda   Blue          45698      4   750000    4.0            4.00
# 7   honda   Blue          54738      4   700000    4.0            5.00
# 8  toyota  White          60000      4   625000    4.0            2.00
# 9  nissan  White          31600      4   970000    4.0            2.00
#
#    Total Fuel used  No of wheels
# 0        6451.8490             6
# 1        6460.5765             6
# 2        1074.1170             6
# 3         595.8407             6
# ...

# %%
car_sales['Passed road safety']=True   #boolean 
car_sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                   int32
# Seats                 float64
# Fuel per 100km        float64
# Total Fuel used       float64
# No of wheels            int64
# Passed road safety       bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   400000    4.0            4.30
# 1   honda    Red          87899      4   500000    4.0            7.35
# 2  toyota   Blue          32549      3   700000    4.0            3.30
# 3     bmw  Black          11179      5  2200000    4.0            5.33
# 4  nissan  White         213095      4   350000    4.0            6.30
# 5  toyota  Green          99213      4   450000    4.0            7.70
# 6   honda   Blue          45698      4   750000    4.0            4.00
# 7   honda   Blue          54738      4   700000    4.0            5.00
# 8  toyota  White          60000      4   625000    4.0            2.00
# 9  nissan  White          31600      4   970000    4.0            2.00
#
#    Total Fuel used  No of wheels  Passed road safety
# 0        6451.8490             6                True
# 1        6460.5765             6                True
# ...

# %%
#Deleting columns

car_sales.drop('Total Fuel used',axis=1) #inline is False here
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   400000    4.0            4.30
# 1   honda    Red          87899      4   500000    4.0            7.35
# 2  toyota   Blue          32549      3   700000    4.0            3.30
# 3     bmw  Black          11179      5  2200000    4.0            5.33
# 4  nissan  White         213095      4   350000    4.0            6.30
# 5  toyota  Green          99213      4   450000    4.0            7.70
# 6   honda   Blue          45698      4   750000    4.0            4.00
# 7   honda   Blue          54738      4   700000    4.0            5.00
# 8  toyota  White          60000      4   625000    4.0            2.00
# 9  nissan  White          31600      4   970000    4.0            2.00
#
#    No of wheels  Passed road safety
# 0             6                True
# 1             6                True
# 2             6                True
# 3             6                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   400000    4.0            4.30
# 1   honda    Red          87899      4   500000    4.0            7.35
# 2  toyota   Blue          32549      3   700000    4.0            3.30
# 3     bmw  Black          11179      5  2200000    4.0            5.33
# 4  nissan  White         213095      4   350000    4.0            6.30
# 5  toyota  Green          99213      4   450000    4.0            7.70
# 6   honda   Blue          45698      4   750000    4.0            4.00
# 7   honda   Blue          54738      4   700000    4.0            5.00
# 8  toyota  White          60000      4   625000    4.0            2.00
# 9  nissan  White          31600      4   970000    4.0            2.00
#
#    Total Fuel used  No of wheels  Passed road safety
# 0        6451.8490             6                True
# 1        6460.5765             6                True
# ...

# %%
car_sales_suffled = car_sales.sample(frac=1)

# %%
car_sales_suffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 6   honda   Blue          45698      4   750000    4.0            4.00
# 4  nissan  White         213095      4   350000    4.0            6.30
# 3     bmw  Black          11179      5  2200000    4.0            5.33
# 1   honda    Red          87899      4   500000    4.0            7.35
# 2  toyota   Blue          32549      3   700000    4.0            3.30
# 7   honda   Blue          54738      4   700000    4.0            5.00
# 9  nissan  White          31600      4   970000    4.0            2.00
# 8  toyota  White          60000      4   625000    4.0            2.00
# 0  toyota  White         150043      4   400000    4.0            4.30
# 5  toyota  Green          99213      4   450000    4.0            7.70
#
#    Total Fuel used  No of wheels  Passed road safety
# 6        1827.9200             6                True
# 4       13424.9850             6                True
# ...

# %%
#only select 20% of data
car_sales_suffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100km  \
# 2  toyota   Blue          32549      3  700000    4.0             3.3
# 7   honda   Blue          54738      4  700000    4.0             5.0
#
#    Total Fuel used  No of wheels  Passed road safety
# 2         1074.117             6                True
# 7         2736.900             6                True

# %%
car_sales_suffled.reset_index(inplace=True,drop=True)
car_sales_suffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0   honda   Blue          45698      4   750000    4.0            4.00
# 1  nissan  White         213095      4   350000    4.0            6.30
# 2     bmw  Black          11179      5  2200000    4.0            5.33
# 3   honda    Red          87899      4   500000    4.0            7.35
# 4  toyota   Blue          32549      3   700000    4.0            3.30
# 5   honda   Blue          54738      4   700000    4.0            5.00
# 6  nissan  White          31600      4   970000    4.0            2.00
# 7  toyota  White          60000      4   625000    4.0            2.00
# 8  toyota  White         150043      4   400000    4.0            4.30
# 9  toyota  Green          99213      4   450000    4.0            7.70
#
#    Total Fuel used  No of wheels  Passed road safety
# 0        1827.9200             6                True
# 1       13424.9850             6                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   400000    4.0            4.30
# 1   honda    Red          87899      4   500000    4.0            7.35
# 2  toyota   Blue          32549      3   700000    4.0            3.30
# 3     bmw  Black          11179      5  2200000    4.0            5.33
# 4  nissan  White         213095      4   350000    4.0            6.30
# 5  toyota  Green          99213      4   450000    4.0            7.70
# 6   honda   Blue          45698      4   750000    4.0            4.00
# 7   honda   Blue          54738      4   700000    4.0            5.00
# 8  toyota  White          60000      4   625000    4.0            2.00
# 9  nissan  White          31600      4   970000    4.0            2.00
#
#    Total Fuel used  No of wheels  Passed road safety
# 0        6451.8490             6                True
# 1        6460.5765             6                True
# ...

# %%
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4   400000    4.0            4.30
# 1   honda    Red      54936.875      4   500000    4.0            7.35
# 2  toyota   Blue      20343.125      3   700000    4.0            3.30
# 3     bmw  Black       6986.875      5  2200000    4.0            5.33
# 4  nissan  White     133184.375      4   350000    4.0            6.30
# 5  toyota  Green      62008.125      4   450000    4.0            7.70
# 6   honda   Blue      28561.250      4   750000    4.0            4.00
# 7   honda   Blue      34211.250      4   700000    4.0            5.00
# 8  toyota  White      37500.000      4   625000    4.0            2.00
# 9  nissan  White      19750.000      4   970000    4.0            2.00
#
#    Total Fuel used  No of wheels  Passed road safety
# 0        6451.8490             6                True
# 1        6460.5765             6                True
# ...
